# %%
import xlrd  
import pandas as pd
from pandas import DataFrame
Corpus = pd.read_excel('dict.xlsx')
thisdict = {}
for i in range(0,len(Corpus)):
    thisdict.update({Corpus['AbusiveWords'][i]:"\u0332".join(Corpus['PoliteWords'][i])})

print(thisdict)
# Out:
# {'กู': 'เ̲ร̲า', 'กุ': 'เ̲ร̲า', 'กรู': 'เ̲ร̲า', 'มึง': 'คุ̲̲ณ', 'เมิง': 'คุ̲̲ณ', 'เมริง': 'คุ̲̲ณ', 'มรึง': 'คุ̲̲ณ', 'มุง': 'คุ̲̲ณ', 'มรุง': 'คุ̲̲ณ', 'เหี้ย': 'แ̲ย่̲', 'ควย': '!̲!̲!', 'สัส': 'ไ̲ม่̲̲ด̲ี', 'ชิบหาย': 'แ̲ย่̲', 'ฉิบหาย': 'แ̲ย่̲', 'ตอแหล': 'โ̲ก̲ห̲ก', 'หน้าด้าน': 'อ̲ด̲ท̲น', 'ดอก': 'แ̲ย่̲', 'กะหรี่': '!̲!̲!', 'ร่าน': 'อ̲ั̲ธ̲ย̲า̲ศ̲ั̲ย̲ด̲ี', 'แรด': 'อ̲ั̲ธ̲ย̲า̲ศ̲ั̲ย̲ด̲ี', 'สันดาน': 'น̲ิ̲ส̲ั̲ย', 'แม่ง': ' ̲!̲!̲!', 'ระยำ': 'แ̲ย่̲', 'แดก': 'ก̲ิ̲น', 'หี': '!̲!̲!', 'หัวดอ': '!̲!̲!', 'กระโปก': '!̲!̲!', 'ซ่อง': 'ส̲ถ̲า̲น̲บ̲ร̲ิ̲ก̲า̲ร', 'ผัว': 'ส̲า̲ม̲ี', 'เมีย': 'ภ̲ร̲ร̲ย̲า', 'ตรู': 'เ̲ร̲า', 'สัด': 'ไ̲ม่̲̲ด̲ี', 'ส้นตีน': 'เ̲ท้̲̲า', 'ห่า': 'ไ̲ม่̲̲ด̲ี', 'เชี้ย': 'แ̲ย่̲', 'โง่': 'ค̲ิ̲ด̲น้̲̲อ̲ย', 'ไอ': 'คุ̲̲ณ', 'อี': 'คุ̲̲ณ', 'อิ': 'คุ̲̲ณ', 'แหก': 'บ̲อ̲ก', 'แตด': '!̲!̲!', 'ตีน': 'เ̲ท้̲̲า', 'แคม': '!̲!̲!', 'อัย': 'คุ̲̲ณ', 'อั่ย': 'คุ̲̲ณ', 'วะ': 'อ̲ะ'}

# %%
thisdict
# Out:
# {'กู': 'เ̲ร̲า',
#  'กุ': 'เ̲ร̲า',
#  'กรู': 'เ̲ร̲า',
#  'มึง': 'คุ̲̲ณ',
#  'เมิง': 'คุ̲̲ณ',
#  'เมริง': 'คุ̲̲ณ',
#  'มรึง': 'คุ̲̲ณ',
#  'มุง': 'คุ̲̲ณ',
#  'มรุง': 'คุ̲̲ณ',
#  'เหี้ย': 'แ̲ย่̲',
#  'ควย': '!̲!̲!',
#  'สัส': 'ไ̲ม่̲̲ด̲ี',
#  'ชิบหาย': 'แ̲ย่̲',
#  'ฉิบหาย': 'แ̲ย่̲',
#  'ตอแหล': 'โ̲ก̲ห̲ก',
#  'หน้าด้าน': 'อ̲ด̲ท̲น',
#  'ดอก': 'แ̲ย่̲',
#  'กะหรี่': '!̲!̲!',
#  'ร่าน': 'อ̲ั̲ธ̲ย̲า̲ศ̲ั̲ย̲ด̲ี',
#  'แรด': 'อ̲ั̲ธ̲ย̲า̲ศ̲ั̲ย̲ด̲ี',
#  'สันดาน': 'น̲ิ̲ส̲ั̲ย',
#  'แม่ง': ' ̲!̲!̲!',
#  'ระยำ': 'แ̲ย่̲',
#  'แดก': 'ก̲ิ̲น',
#  'หี': '!̲!̲!',
#  'หัวดอ': '!̲!̲!',
#  'กระโปก': '!̲!̲!',
#  'ซ่อง': 'ส̲ถ̲า̲น̲บ̲ร̲ิ̲ก̲า̲ร',
#  'ผัว': 'ส̲า̲ม̲ี',
#  'เมีย': 'ภ̲ร̲ร̲ย̲า',
#  'ตรู': 'เ̲ร̲า',
#  'สัด': 'ไ̲ม่̲̲ด̲ี',
#  'ส้นตีน': 'เ̲ท้̲̲า',
#  'ห่า': 'ไ̲ม่̲̲ด̲ี',
#  'เชี้ย': 'แ̲ย่̲',
#  'โง่': 'ค̲ิ̲ด̲น้̲̲อ̲ย',
#  'ไอ': 'คุ̲̲ณ',
#  'อี': 'คุ̲̲ณ',
#  'อิ': 'คุ̲̲ณ',
#  'แหก': 'บ̲อ̲ก',
#  'แตด': '!̲!̲!',
#  'ตีน': 'เ̲ท้̲̲า',
#  'แคม': '!̲!̲!',
#  'อัย': 'คุ̲̲ณ',
#  'อั่ย': 'คุ̲̲ณ',
#  'วะ': 'อ̲ะ'}
